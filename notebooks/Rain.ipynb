# %%
import pandas as pd

train_df = pd.read_csv('C:/AA/kaggle/rain/train.csv')
test_df = pd.read_csv('C:/AA/kaggle/rain/test.csv')

# %%
train_df.shape
# Out:
# (13765201, 24)

# %%
train_df.head(35)
# Out:
#     Id  minutes_past  radardist_km   Ref  Ref_5x5_10th  Ref_5x5_50th  \
# 0    1             3            10   NaN           NaN           NaN
# 1    1            16            10   NaN           NaN           NaN
# 2    1            25            10   NaN           NaN           NaN
# 3    1            35            10   NaN           NaN           NaN
# 4    1            45            10   NaN           NaN           NaN
# 5    1            55            10   NaN           NaN           NaN
# 6    2             1             2   9.0           5.0           7.5
# 7    2             6             2  26.5          22.5          25.5
# 8    2            11             2  21.5          15.5          20.5
# 9    2            16             2  18.0          14.0          17.5
# 10   2            21             2  24.5          16.5          21.0
# 11   2            26             2  12.0          12.0          16.0
# 12   2            31             2  22.5          19.0          22.0
# ...

# %%
# Out:
# 0.010000005

# %%
test_df.head(30)
# Out:
#     Id  minutes_past  radardist_km   Ref  Ref_5x5_10th  Ref_5x5_50th  \
# 0    1             1             8   NaN           NaN           NaN
# 1    1             5             8  10.0           NaN          10.0
# 2    1             8             8   NaN           NaN           7.0
# 3    1            12             8  14.0           NaN           9.0
# 4    1            15             8  10.5           NaN           9.0
# 5    1            19             8   8.0           NaN           9.0
# 6    1            23             8   6.5           NaN           7.0
# 7    1            26             8  16.0           NaN           8.5
# 8    1            30             8   7.0           NaN           8.0
# 9    1            33             8  12.0           NaN           7.0
# 10   1            37             8   NaN           NaN           NaN
# 11   1            41             8   NaN           NaN           NaN
# 12   1            44             8   NaN           NaN           NaN
# ...

# %%
m= train_df.mean()
v= train_df.var()

# %%
train_df.count()
# Out:
# Id                       13765201
# minutes_past             13765201
# radardist_km             13765201
# Ref                       6349375
# Ref_5x5_10th              5283988
# Ref_5x5_50th              6356482
# Ref_5x5_90th              7551281
# RefComposite              6716343
# RefComposite_5x5_10th     5755673
# RefComposite_5x5_50th     6711663
# RefComposite_5x5_90th     7829203
# RhoHV                     4934916
# RhoHV_5x5_10th            4133154
# RhoHV_5x5_50th            4936568
# RhoHV_5x5_90th            5905584
# Zdr                       4934916
# Zdr_5x5_10th              4133154
# Zdr_5x5_50th              4936568
# Zdr_5x5_90th              5905584
# Kdp                       4182635
# Kdp_5x5_10th              3428782
# Kdp_5x5_50th              4187281
# Kdp_5x5_90th              5052776
# Expected                 13765201
# dtype: int64

# %%
m
# Out:
# Id                       592336.986614
# minutes_past                 29.523733
# radardist_km                 11.067943
# Ref                          22.926658
# Ref_5x5_10th                 19.952271
# Ref_5x5_50th                 22.610287
# Ref_5x5_90th                 25.898461
# RefComposite                 24.711081
# RefComposite_5x5_10th        22.158238
# RefComposite_5x5_50th        24.420753
# RefComposite_5x5_90th        27.368961
# RhoHV                         0.972890
# RhoHV_5x5_10th                0.918859
# RhoHV_5x5_50th                0.974400
# RhoHV_5x5_90th                1.015272
# Zdr                           0.536709
# Zdr_5x5_10th                 -0.719008
# Zdr_5x5_50th                  0.337622
# Zdr_5x5_90th                  2.072870
# Kdp                           0.035452
# Kdp_5x5_10th                 -3.482325
# Kdp_5x5_50th                 -0.473655
# Kdp_5x5_90th                  4.079836
# Expected                    108.626306
# ...

# %%
train_df.isnull().sum()
# Out:
# Id                              0
# minutes_past                    0
# radardist_km                    0
# Ref                       7415826
# Ref_5x5_10th              8481213
# Ref_5x5_50th              7408719
# Ref_5x5_90th              6213920
# RefComposite              7048858
# RefComposite_5x5_10th     8009528
# RefComposite_5x5_50th     7053538
# RefComposite_5x5_90th     5935998
# RhoHV                     8830285
# RhoHV_5x5_10th            9632047
# RhoHV_5x5_50th            8828633
# RhoHV_5x5_90th            7859617
# Zdr                       8830285
# Zdr_5x5_10th              9632047
# Zdr_5x5_50th              8828633
# Zdr_5x5_90th              7859617
# Kdp                       9582566
# Kdp_5x5_10th             10336419
# Kdp_5x5_50th              9577920
# Kdp_5x5_90th              8712425
# Expected                        0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.pairplot(train_df[["radardist_km", "Expected"]])
plt.show()
# Out:
# C:\TOOLS\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
type(train_df.target[0])
# Out:
# numpy.int64

# %%
import numpy as np
df_null = train_df.isnull()
df_null.Id = train_df.Id
item_null = df_null.groupby('Id').sum()
item_null.Expected = train_df.groupby('Id').agg({'Expected':np.mean})
item_null
# Out:
#          minutes_past  radardist_km  Ref  Ref_5x5_10th  Ref_5x5_50th  \
# Id
# 1                   0             0    6             6             6
# 2                   0             0    0             0             0
# 3                   0             0   12            12            12
# 4                   0             0    3             6             3
# 5                   0             0   14            14            14
# 6                   0             0    6             6             6
# 7                   0             0   13            14            11
# 8                   0             0    2             6             2
# 9                   0             0   13            13            13
# 10                  0             0    0             0             0
# 11                  0             0    0             0             0
# 12                  0             0    0             0             0
# ...

# %%
train_df[train_df.Id == 1180941]
# Out:
#                Id  minutes_past  radardist_km  Ref  Ref_5x5_10th  \
# 13765146  1180941             7            15  NaN           NaN
# 13765147  1180941            17            15  NaN           NaN
# 13765148  1180941            26            15  NaN           NaN
# 13765149  1180941            36            15  NaN           NaN
# 13765150  1180941            46            15  NaN           NaN
# 13765151  1180941            55            15  NaN           NaN
#
#           Ref_5x5_50th  Ref_5x5_90th  RefComposite  RefComposite_5x5_10th  \
# 13765146           NaN           NaN           NaN                    NaN
# 13765147           NaN           NaN           NaN                    NaN
# 13765148           NaN           NaN           NaN                    NaN
# 13765149           NaN           NaN           NaN                    NaN
# 13765150           NaN           NaN           NaN                    NaN
# ...

# %%
train_df[train_df.Id == 1180940]
# Out:
#                Id  minutes_past  radardist_km  Ref  Ref_5x5_10th  \
# 13765135  1180940             1            15  NaN           NaN
# 13765136  1180940             7            15  NaN           NaN
# 13765137  1180940            12            15  NaN           NaN
# 13765138  1180940            18            15  NaN           NaN
# 13765139  1180940            24            15  NaN           NaN
# 13765140  1180940            30            15  NaN           NaN
# 13765141  1180940            36            15  NaN           NaN
# 13765142  1180940            41            15  NaN           NaN
# 13765143  1180940            47            15  NaN           NaN
# 13765144  1180940            53            15  NaN           NaN
# 13765145  1180940            59            15  NaN           NaN
#
#           Ref_5x5_50th  Ref_5x5_90th  RefComposite  RefComposite_5x5_10th  \
# 13765135           NaN           NaN           NaN                    NaN
# ...

# %%
dist_expected = train_df.groupby('Id').agg({'radardist_km':np.mean, 'Expected': np.mean})
dist_expected
# Out:
#             Expected  radardist_km
# Id
# 1           0.254000            10
# 2           1.016001             2
# 3          26.162014            10
# 4           4.064002             9
# 5         774.700440            13
# 6           0.254000            13
# 7           0.508000            13
# 8           3.225002             8
# 9          18.288010            18
# 10          0.010000            10
# 11          2.540001            12
# 12          3.302002             6
# 13          0.254000            17
# 14          1.270001            14
# 15          2.286001            14
# 16       1308.100700            13
# 17          0.060000            14
# 18          1.524001            13
# 19          3.810002            16
# 20          0.254000            15
# 21         28.000013             7
# 22        166.370090            10
# 23          1.270001            14
# 24          1.075001            11
# 25          1.016000            17
# ...

# %%
sns.pairplot(dist_expected[["radardist_km", "Expected"]])
plt.figure(figsize=(12,12))
plt.show()
# Out:
# C:\TOOLS\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
